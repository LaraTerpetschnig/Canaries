# %%
import pandas as pd

# %%
meal_gap = pd.read_csv('../data/Meal_Gap_2019.csv')

# %%
meal_gap.shape
# Out:
# (3142, 20)

# %%
meal_gap.head()
# Out:
#    FIPS State          County  pctFoodInsecure  numFoodInsecure  \
# 0  1001    AL  Autauga County            0.157           8670.0
# 1  1003    AL  Baldwin County            0.134          28590.0
# 2  1005    AL  Barbour County            0.207           5250.0
# 3  1007    AL     Bibb County            0.163           3680.0
# 4  1009    AL   Blount County            0.145           8380.0
#
#    pctBlackFoodInsecure  pctLatineFoodInsecure  pctWhiteFoodInsecure  \
# 0                  0.26                    NaN                  0.12
# 1                  0.26                   0.10                  0.11
# 2                  0.34                    NaN                  0.14
# 3                  0.28                    NaN                  0.14
# 4                  0.14                   0.11                  0.12
#
#    SNAPthreshold  pctFIbelowSNAP  pctFIaboveSNAP  pctKidsFoodInsecure  \
# 0            1.3           0.486           0.514                0.196
# ...

# %%
meal_gap.dtypes
# Out:
# FIPS                               int64
# State                                str
# County                               str
# pctFoodInsecure                  float64
# numFoodInsecure                  float64
# pctBlackFoodInsecure             float64
# pctLatineFoodInsecure            float64
# pctWhiteFoodInsecure             float64
# SNAPthreshold                    float64
# pctFIbelowSNAP                   float64
# pctFIaboveSNAP                   float64
# pctKidsFoodInsecure              float64
# numKidsFoodInsecure              float64
# pctKidsIncomeBelow185            float64
# pctKidsIncomeAbove185            float64
# costPerMeal                      float64
# weeklyFoodBudget                 float64
# weeklyBudgetFoodInsecureByPop    float64
# rangeRuralUrban                  float64
# USstateRegion                        str
# dtype: object

# %%
meal_gap.isna().sum()
# Out:
# FIPS                                0
# State                               0
# County                              0
# pctFoodInsecure                     0
# numFoodInsecure                     0
# pctBlackFoodInsecure             1611
# pctLatineFoodInsecure            1366
# pctWhiteFoodInsecure               41
# SNAPthreshold                       0
# pctFIbelowSNAP                      0
# pctFIaboveSNAP                      0
# pctKidsFoodInsecure                 0
# numKidsFoodInsecure                 0
# pctKidsIncomeBelow185               0
# pctKidsIncomeAbove185               0
# costPerMeal                         0
# weeklyFoodBudget                    0
# weeklyBudgetFoodInsecureByPop       0
# rangeRuralUrban                     0
# USstateRegion                       0
# dtype: int64

# %%
meal_gap['State'].unique()
# Out:
# <StringArray>
# ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID',
#  'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO',
#  'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA',
#  'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
# Length: 51, dtype: str

# %%
meal_gap['rangeRuralUrban'].describe()
# Out:
# count    3142.000000
# mean        5.008593
# std         2.708411
# min         1.000000
# 25%         2.000000
# 50%         6.000000
# 75%         7.000000
# max         9.000000
# Name: rangeRuralUrban, dtype: float64

# %%
len(meal_gap['FIPS'].unique())
# Out:
# 3142

# %%
meal_gap['County, State'] = meal_gap['County'] + ', ' + meal_gap['State']

# %%
len(meal_gap['County, State'].unique())
# Out:
# 3142
